# %% [markdown]
# # 本次專案作業參考了YOLOv4 (https://github.com/WongKinYiu/PyTorch_YOLOv4) 和YOLOv7 (https://github.com/WongKinYiu/yolov7) 進行訓練，並將圖片前處理、Tesseract OCR等等功能加在兩個模型的detect.py代碼內，整個實驗在Anaconda Powershell底下執行，為方便學長查看大致流程，我將當時訓練的大致步驟貼於此，方便查看，影片辨識的部分兩個模型我各拿其中一個結果放在其模型資料內

# %%
cd C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master
# Out:
# C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master

# %%
import cv2
import matplotlib.pyplot as plt

# %%
# %run train.py --batch-size 4 --img 512 512 --data od.yaml --cfg od.cfg --weights weights/yolo4.weights --name yolov4 --epochs 100
# Out:
# Using torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MB)
#
# Namespace(weights='weights/yolo4.weights', cfg='.\\cfg\\od.cfg', data='od.yaml', hyp='data/hyp.scratch.yaml', epochs=100, batch_size=4, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, log_imgs=16, workers=8, project='runs/train', name='yolov4', exist_ok=False, total_batch_size=4, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov44')
# Start Tensorboard with "tensorboard --logdir runs/train", view at http://localhost:6006/
# ...

# %%
# %run test.py --img 512 --conf 0.001 --batch 4 --device 0 --data od.yaml --cfg cfg/od.cfg --weights weights/best.pt
# Out:
# Using torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MB)
# Namespace(weights=['weights/best.pt'], data='od.yaml', batch_size=4, img_size=512, conf_thres=0.001, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_conf=False, save_json=False, project='runs/test', name='exp', exist_ok=False, cfg='cfg/od.cfg', names='data/coco.names')
# C:\Users\Chen\anaconda3\envs\yolo\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 488 layers, 63937686 parameters, 63937686 gradients, 141.900185600 GFLOPS
# Scanning labels val.cache3 (536 found, 0 missing, 0 empty, 0 duplicate, for 536 images): 536it [00:00, 20669.38it/s]
# ...

# %%
image_path = 'C:/Users/Chen/Desktop/ML3/PyTorch_YOLOv4-master/inference/output/image_0011.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
# %run detect.py --weights weights/best.pt --source ./image_0011.jpg
# Out:
# Namespace(weights=['weights/best.pt'], source='./image_0011.jpg', output='inference/output', img_size=512, conf_thres=0.4, iou_thres=0.5, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False, update=False, cfg='cfg/od.cfg', names='od.names')
# image 1/1 C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\image_0011.jpg: Detected Text: 1SSUT50994
# Image Text: image_0011
# 320x512 1 containers, Done. (0.016s)
# OCR Accuracy: 0.00%
# Results saved to inference\output
# Done. (1.337s)

# %%
image_path = 'C:/Users/Chen/Desktop/ML3/PyTorch_YOLOv4-master/inference/output/image_0011.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
image_path = 'C:/Users/Chen/Desktop/ML3/PyTorch_YOLOv4-master/inference/output/image_0011_735_26_932_104.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
# %run detect.py --weights weights/best.pt --source ./accuracytest/
# Out:
# Namespace(weights=['weights/best.pt'], source='./accuracytest/', output='inference/output', img_size=512, conf_thres=0.4, iou_thres=0.5, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False, update=False, cfg='cfg/od.cfg', names='od.names')
# image 1/35 C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\accuracytest\FFAU2895947.jpg: Detected Text: FAU2695947
# Image Text: FFAU289594
# 320x512 1 containers, Done. (0.090s)
# OCR Accuracy: 0.00%
# image 2/35 C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\accuracytest\MAGU5605323 .jpg: Detected Text: MBG560532K
# Image Text: MAGU560532
# 320x512 1 containers, Done. (0.075s)
# OCR Accuracy: 0.00%
# image 3/35 C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\accuracytest\SEKU5875349.jpg: Detected Text: SEKU587534
# Image Text: SEKU587534
# 320x512 1 containers, Done. (0.174s)
# OCR Accuracy: 33.33%
# ...

# %%
# %run detectv.py --weights weights/best.pt --source ./video/WHSU6892256.avi
# Out:
# Namespace(weights=['weights/best.pt'], source='./video/WHSU6892256.avi', output='inference/output', img_size=512, conf_thres=0.4, iou_thres=0.5, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False, update=False, cfg='cfg/od.cfg', names='od.names')
# C:\Users\Chen\anaconda3\envs\yolo\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# video 1/1 (1/108) C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\video\WHSU6892256.avi: Detected Text: WHSUSOSASC
# 320x512 1 containers, Done. (0.090s)
# video 1/1 (2/108) C:\Users\Chen\Desktop\ML3\PyTorch_YOLOv4-master\video\WHSU6892256.avi: Detected Text: WHSU689225
# 320x512 1 containers, Done. (0.016s)
# ...

# %%
cd C:\Users\Chen\Desktop\yolov7-main
# Out:
# C:\Users\Chen\Desktop\yolov7-main

# %%
# %run train.py --batch 4 --cfg cfg/training/yolov7.yaml --img 512 512 --epochs 100 --data coco.yaml --weights yolov7.pt --name yolov7 --hyp data/hyp.scratch.p5.yaml --device 0
# Out:
# YOLOR  2023-3-4 torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7.yaml', data='.\\data\\coco.yaml', hyp='data/hyp.scratch.p5.yaml', epochs=100, batch_size=4, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='yolov7', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs\\train\\yolov7', total_batch_size=4)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# %run test.py --data data/coco.yaml --img 512 --batch 4 --conf 0.001 --device 0 --weights best.pt --name yolov7
# Out:
# YOLOR  2023-3-4 torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
# Namespace(weights=['best.pt'], data='data/coco.yaml', batch_size=4, img_size=512, conf_thres=0.001, iou_thres=0.65, task='val', device='0', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project='runs/test', name='yolov7', exist_ok=False, no_trace=False, v5_metric=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
# val: Scanning 'customdata\val.cache' images and labels... 536 found, 0 missing, 0 empty, 0 corrupted: 100%|█| 536/536 [
#                Class      Images      Labels           P           R      mAP@.5  mAP@.5:.95: 100%|█| 134/134 [00:06<00
# ...

# %%
# %run detect.py --weights ./best.pt --img-size 512 --source ./image_0011.jpg
# Out:
# YOLOR  2023-3-4 torch 2.0.0+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287.5MB)
# Namespace(weights=['./best.pt'], source='./image_0011.jpg', img_size=512, conf_thres=0.5, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# C:\Users\Chen\anaconda3\envs\yolo\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# ...

# %%
image_path = 'C:/Users/Chen/Desktop/yolov7-main/runs/detect/exp/image_0011.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
image_path = 'C:/Users/Chen/Desktop/yolov7-main/runs/detect/exp/image_0011_734_24_933_104.jpg'
image = cv2.imread(image_path)

image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
# %run detectv.py --weights weights/best.pt --source ./video/WHSU6892256.avi
